# %% [markdown]
# # Setup

# %%
# !pip install python-dotenv  

import os 
import pandas as pd
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
# Retrieve API key
NEWSAPI_API_KEY = os.getenv("NEWSAPI_API_KEY")
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

# get_api_key function
def get_api_key(key_name):
    load_dotenv()
    return os.getenv(key_name)

# %%
from newsapi import NewsApiClient

newsapi_key = get_api_key("NEWSAPI_API_KEY")
newsapi = NewsApiClient(api_key=get_api_key("NEWSAPI_API_KEY"))

# %% [markdown]
# # LLM Implementation and Similarity Search

# %% [markdown]
# ### LLM Interface, Similiarity Search

# %%
# LLM Interface
#!pip install ollama dspy
import ollama
import dspy
lm = dspy.LM("ollama/mistral")  # or you can use "ollama/mistral" as another option
dspy.configure(lm=lm)

# %%
class UserPreferenceChat(dspy.Module):
    def __init__(self):
        super().__init__()
        self.gen = dspy.ChainOfThought("chat_input -> structured_output")

    def forward(self, chat_input):
        prompt = f"""
        Act as a friendly news personalization assistant. Based on this chat input: '{chat_input}'
        
        1. Extract or infer the user's current mood
        2. Extract or infer their news interests
        3. Return the information in this exact format:
        MOOD: [extracted mood]
        INTERESTS: [comma-separated list of interests]
        
        Keep the response concise and only return the formatted information.
        """

        response = self.gen(chat_input=prompt).structured_output
        return response


def llm_chat_preferences():
    """
    LLM-powered chat function to collect user preferences
    Returns tuple of (mood_in, q_entries)
    """
    print("Hello! I'm your news personalization assistant.")
    print("Tell me how you're feeling and what kind of news interests you.")
    print(
        "For example: 'I'm feeling energetic today and would love to read about tech startups and space exploration'"
    )

    user_input = input("\nYou: ").strip()

    # Process with LLM
    processor = UserPreferenceChat()
    result = processor(user_input)

    # Parse LLM response
    try:
        mood_line = [line for line in result.split("\n") if line.startswith("MOOD:")][0]
        interests_line = [
            line for line in result.split("\n") if line.startswith("INTERESTS:")
        ][0]

        mood_in = mood_line.replace("MOOD:", "").strip()
        q_entries = interests_line.replace("INTERESTS:", "").strip()

        # Confirm with user
        print("\nI understood your preferences as:")
        print(f"Mood: {mood_in}")
        print(f"Interests: {q_entries}")

        return mood_in, q_entries

    except Exception as e:
        print(f"Error processing response: {str(e)}")
        return None, None


# Use the function and create user_prefs
try:
    mood_in, q_entries = llm_chat_preferences()
    if mood_in and q_entries:
        user_prefs = {"mood": mood_in, "news_interests": q_entries}
    else:
        print("Failed to get preferences. Please try again.")

except Exception as e:
    print(f"An error occurred: {str(e)}")
# Out:
# Hello! I'm your news personalization assistant.
# Tell me how you're feeling and what kind of news interests you.
# For example: 'I'm feeling energetic today and would love to read about tech startups and space exploration'
#
# I understood your preferences as:
# Mood: Sadness or Disappointment
# Interests: Health, Universities

# %%
# check LLM output
print(mood_in, q_entries)
# Out:
# Sadness or Disappointment Health, Universities

# %%
# save topics for later use
topics = [topic.strip().replace("'","").replace('"','') for topic in q_entries.split(",")]
print(topics)
# Out:
# ['Health', 'Universities']

# %% [markdown]
# ### Fetch the news articles

# %%
sort_criteria = "popularity"
json_out = newsapi.get_everything(q=q_entries, sort_by=sort_criteria, language="en", page_size=100) # removed q=q_entries
type(json_out)
print(json_out)
# Out:
# {'status': 'ok', 'totalResults': 993, 'articles': [{'source': {'id': None, 'name': 'BBC News'}, 'author': None, 'title': 'Too much debt or value for money? Students divided over tuition fee rise', 'description': 'University fees are rising to £9,535, meaning students will be left in more debt after their course.', 'url': 'https://www.bbc.com/news/articles/crr92910r55o', 'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/be63/live/276e69e0-9e04-11ef-8538-e1655f5a8342.jpg', 'publishedAt': '2024-11-10T00:30:22Z', 'content': 'Isobel, 18, decided she "did not want the debt" from going to university \r\nTuition fees are rising for undergraduate students at universities in England for the first time in eight years.\r\nStudents f… [+8305 chars]'}, {'source': {'id': None, 'name': 'NPR'}, 'author': 'Rob Stein', 'title': 'With Trump coming into power, the NIH is in the crosshairs', 'description': 'The National Institutes of Health, the crown jewel of biomedical research in the U.S., could face big changes under the new Trump administration, some fueled by pandemic-era criticisms of the agency.', 'url': 'https://www.npr.org/2024/11/12/nx-s1-5183014/trump-election-2024-nih-rfk', 'urlToImage': 'https://npr.brightspotcdn.com/dims3/default/strip/false/crop/1024x576+0+0/resize/1400/quality/100/format/jpeg/?url=http%3A%2F%2Fnpr-brightspot.s3.amazonaws.com%2F83%2F12%2Fe126193e4b8183640898cd04cda2%2Fgettyimages-937109072.jpg', 'publishedAt': '2024-11-12T18:16:08Z', 'content': 'As the next Trump administration overhauls the federal government, the National Institutes of Health could be among the top targets for restructuring.\r\n"I do think you probably will see changes in NI… [+7160 chars]'}, {'source': {'id': None, 'name': 'NPR'}, 'author': 'Martha Bebinger', 'title': 'Instead of sodas, these vending machines offer needles and Narcan to fight overdoses', 'description': 'Groups trying to reduce overdose deaths and the spread of infectious diseases are using vending machines to get clean needles, pipes, wound care kits, Narcan and other safety supplies to drug users.', 'url': 'https://www.npr.org/sections/shots-health-news/2024/11/13/nx-s1-5189599/harm-reduction-opioid-overdoses-vending-machine-narcan-clean-needles-epidemic-fentanyl-xylazine', 'urlToImage': 'https://npr.brightspotcdn.com/dims3/default/strip/false/crop/4032x2268+0+117/resize/1400/quality/100/format/jpeg/?url=http%3A%2F%2Fnpr-brightspot.s3.amazonaws.com%2F0d%2F3e%2F3272f8764c438ec05f540bac4cc7%2Fimg-3612-2-1.jpg', 'publishedAt': '2024-11-14T13:00:00Z', 'content': 'The small city of North Adams, nestled in the Berkshires of western Massachusetts, is well-know as a hub of contemporary art, a bucolic haven for stressed New Yorkers, and an autumn leaf peeping dest… [+8570 chars]'}, {'source': {'id': None, 'name': 'Yahoo Entertainment'}, 'author': 'Lou Carlozo', 'title': '5 surprising things American retirees should spend money on sooner rather than later', 'description': "No, travel isn't one of them.", 'url': 'https://finance.yahoo.com/news/5-surprising-things-american-retirees-114900792.html', 'urlToImage': 'https://media.zenfs.com/en/moneywise_327/73059d837868d1e0de2610f1934bc31e', 'publishedAt': '2024-12-05T11:49:00Z', 'content': 'Youll find plenty of articles and social media posts telling you what not to spend money on in retirement from big-ticket items like lavish cruises to little indulgences that can add up over time (th… [+6179 chars]'}, {'source': {'id': None, 'name': 'Digital Trends'}, 'author': 'Andrew Tarantola', 'title': 'The brain-computer interface revolution is just getting started', 'description': "Brain-Computer Interfaces fascinate the sci-fi and medical communities in equal measure, here's how close the transformative technology is to everyday use.", 'url': 'https://www.digitaltrends.com/computing/tech-for-change-brain-computer-interface/', 'urlToImage': 'https://www.digitaltrends.com/wp-content/uploads/2024/11/who-its-for.BxcXFghW.webp?resize=1200%2C6 ...

# %%
# Populate dataframe with all relevant articles
df = pd.DataFrame(json_out["articles"])
#df.drop(columns=["source", "author", "urlToImage", "publishedAt"], inplace=True)
df.head(10)
# Out:
#                                         source             author  \
# 0             {'id': None, 'name': 'BBC News'}               None
# 1                  {'id': None, 'name': 'NPR'}          Rob Stein
# 2                  {'id': None, 'name': 'NPR'}    Martha Bebinger
# 3  {'id': None, 'name': 'Yahoo Entertainment'}        Lou Carlozo
# 4       {'id': None, 'name': 'Digital Trends'}   Andrew Tarantola
# 5         {'id': None, 'name': 'The Atlantic'}       David Brooks
# 6      {'id': None, 'name': 'Popular Science'}       RJ Mackenzie
# 7       {'id': None, 'name': 'Android Police'}        Jon Gilbert
# 8       {'id': None, 'name': 'Android Police'}  Nathaniel Wilkins
# 9        {'id': None, 'name': 'Science Daily'}               None
#
#                                                title  \
# 0  Too much debt or value for money? Students div...
# 1  With Trump coming into power, the NIH is in th...
# 2  Instead of sodas, these vending machines offer...
# 3  5 surprising things American retirees should s...
# 4  The brain-computer interface revolution is jus...
# 5                   How the Ivy League Broke America
# 6  What happens when you donate your body to scie...
# 7  Empire: Total War for Android is much more tha...
# 8  Google's Audio Overview can transform bland re...
# 9  Building green and blue spaces, such as parks,...
#
#                                          description  \
# 0  University fees are rising to £9,535, meaning ...
# 1  The National Institutes of Health, the crown j...
# 2  Groups trying to reduce overdose deaths and th...
# 3                      No, travel isn't one of them.
# 4  Brain-Computer Interfaces fascinate the sci-fi...
# 5  The meritocracy isn’t working. We need somethi...
# 6  'They will be teaching over 3,000 healthcare p...
# 7  Empire: Total War's new features are only foun...
# 8  No more slogging through long documents. Find ...
# 9  With house building a priority for the new UK ...
#
#                                                  url  \
# 0     https://www.bbc.com/news/articles/crr92910r55o
# 1  https://www.npr.org/2024/11/12/nx-s1-5183014/t...
# 2  https://www.npr.org/sections/shots-health-news...
# 3  https://finance.yahoo.com/news/5-surprising-th...
# 4  https://www.digitaltrends.com/computing/tech-f...
# 5  https://www.theatlantic.com/magazine/archive/2...
# 6  https://www.popsci.com/health/what-happens-whe...
# 7  https://www.androidpolice.com/total-war-empire...
# 8  https://www.androidpolice.com/google-audio-ove...
# 9  https://www.sciencedaily.com/releases/2024/12/...
#
#                                           urlToImage           publishedAt  \
# 0  https://ichef.bbci.co.uk/news/1024/branded_new...  2024-11-10T00:30:22Z
# 1  https://npr.brightspotcdn.com/dims3/default/st...  2024-11-12T18:16:08Z
# 2  https://npr.brightspotcdn.com/dims3/default/st...  2024-11-14T13:00:00Z
# 3  https://media.zenfs.com/en/moneywise_327/73059...  2024-12-05T11:49:00Z
# 4  https://www.digitaltrends.com/wp-content/uploa...  2024-11-16T00:13:17Z
# 5  https://cdn.theatlantic.com/thumbor/ISbKcAvvYE...  2024-11-14T11:00:00Z
# 6  https://www.popsci.com/wp-content/uploads/2024...  2024-11-24T13:03:00Z
# 7  https://static1.anpoimages.com/wordpress/wp-co...  2024-11-19T14:53:17Z
# 8  https://static1.anpoimages.com/wordpress/wp-co...  2024-11-11T15:17:03Z
# 9  https://www.sciencedaily.com/images/scidaily-i...  2024-12-03T20:44:33Z
#
#                                              content
# 0  Isobel, 18, decided she "did not want the debt...
# 1  As the next Trump administration overhauls the...
# 2  The small city of North Adams, nestled in the ...
# 3  Youll find plenty of articles and social media...
# 4  Whether it’s jacking into the Matrix or becomi...
# 5  Every coherent society has a social idealan im...
# 6  We may earn revenue from the products availabl...
# 7  Over the years, Feral Interactive has ported s...
# 8  Google's AI-powered NotebookLM has fully arriv...
# 9  With house building a priority for the new UK ...

# %% [markdown]
# I am using similarity search to find more relevant articles, even after filtering by topic within the newsapi method call. Treat the newsapi method call parameter as a first pass filter, and the similarity search as a more refined 'search'.
#
# I use this method to increase the maximum search results while retaining the most relevancy.

# %%
# Testing different models for similarity search
# !pip install faiss-cpu hnswlib --quiet

# %%
# Import libraries
from sentence_transformers import SentenceTransformer
import numpy as np
import faiss
import hnswlib

# Set max results 
MAX_RESULTS = 20

# Initialize the sentence transformer
model = SentenceTransformer("all-MiniLM-L6-v2")

def create_embeddings(texts):
    return model.encode(texts, show_progress_bar=False)

# FAISS

def search_faiss(query_embedding, embeddings, k=MAX_RESULTS):
    # Initialize FAISS index
    dimension = embeddings.shape[1]
    index = faiss.IndexFlatL2(dimension)
    index.add(embeddings.astype("float32"))

    # Search
    distances, indices = index.search(query_embedding.reshape(1, -1), k)
    return indices[0]

# HNSW

def search_hnsw(query_embedding, embeddings, k=MAX_RESULTS):
    # Initialize HNSW index
    dimension = embeddings.shape[1]
    index = hnswlib.Index(space="l2", dim=dimension)
    index.init_index(max_elements=len(embeddings), ef_construction=200, M=16)
    index.add_items(embeddings)

    # Search
    labels, distances = index.knn_query(query_embedding.reshape(1, -1), k=k)
    return labels[0]


# Create embeddings for all articles
content_embeddings = create_embeddings(df["content"].values)

# Store results for each topic using both methods
faiss_results = {}
hnsw_results = {}

# %%
# Initialize empty DataFrames for results
faiss_results = pd.DataFrame()
hnsw_results = pd.DataFrame()

for topic in topics:
    # Create query embedding
    query_embedding = create_embeddings([topic])[0]

    # FAISS search
    faiss_indices = search_faiss(query_embedding, content_embeddings)
    topic_results = df.iloc[faiss_indices].copy()
    topic_results['topic'] = topic
    faiss_results = pd.concat([faiss_results, topic_results])

    # HNSW search 
    hnsw_indices = search_hnsw(query_embedding, content_embeddings)
    topic_results = df.iloc[hnsw_indices].copy()
    topic_results['topic'] = topic
    hnsw_results = pd.concat([hnsw_results, topic_results])

# Example to view results
print("\nFAISS Results:")
for topic in topics:
    print(f"\nTop articles for '{topic}':")
    print(faiss_results[faiss_results['topic'] == topic]['title'])

print("\nHNSW Results:")
for topic in topics:
    print(f"\nTop articles for '{topic}':")
    print(hnsw_results[hnsw_results['topic'] == topic]['title'])
# Out:
# FAISS Results:
#
# Top articles for 'Health':
# 52                                  No Meta Status Orgs
# 53    Suggested questions for Donald Trump’s health ...
# 1     With Trump coming into power, the NIH is in th...
# 77    Survey: Supporting Students Postelection, in 4...
# 88    Can RFK Jr. Fix Our Dysfunctional Public Healt...
# 15    Q&A: Researcher discusses protecting the healt...
# 96    Karachi’s Air Quality Crisis: A Call for Urgen...
# 38    1 In 5 Gen Z Healthcare Workers Are Considerin...
# 78         Imagining More Sustainable Higher Ed Careers
# 54    RFK Jr. vs. the NIH: Say goodbye to the greate...
# 73    ‘How the World Ran Out of Everything’ and ‘Rec...
# 65                  Trump Taps Bhattacharya to Lead NIH
# 69    Robert F. Kennedy Jr.'s Appointment Would 'Put...
# 
# 67    Republicans, Back in Charge of Congress, Aim t...
# 31    A Post-Election Analysis On The Value Of Colle...
# 84    Listen: How Life Design Can Improve Student Su...
# 74    Colleges Must Recommit to Serving Those Who Se...
# 29    How To Support Faculty And Staff Who Support S...
# 41    5 Study Habits Every Ivy League Hopeful Should...
# 76          How Higher Ed Can ‘Safeguard’ for Democracy
# 82                    Academic Probation Gets a Rebrand
# 75    5 Questions for an Expert on Interdisciplinary...
# 79    Red States Back Trump’s Plan to Abolish Educat...
# 30    Acknowledging The Needs Of College Students Wh...
# Name: title, dtype: object

# %%
print(faiss_results.head(40))
print(hnsw_results.head(40))
print(len(faiss_results), len(hnsw_results))
# Out:
#                                               source  \
# 52        {'id': None, 'name': 'Overcomingbias.com'}
# 53  {'id': None, 'name': 'Sciencebasedmedicine.org'}
# 1                        {'id': None, 'name': 'NPR'}
# 77          {'id': None, 'name': 'Inside Higher Ed'}
# 88                    {'id': None, 'name': 'Reason'}
# 15                  {'id': None, 'name': 'Phys.Org'}
# 96              {'id': None, 'name': 'The Diplomat'}
# 38                    {'id': None, 'name': 'Forbes'}
# 78          {'id': None, 'name': 'Inside Higher Ed'}
# 54  {'id': None, 'name': 'Sciencebasedmedicine.org'}
# 73          {'id': None, 'name': 'Inside Higher Ed'}
# 65          {'id': None, 'name': 'Inside Higher Ed'}
# 69          {'id': None, 'name': 'Inside Higher Ed'}
# 48    {'id': None, 'name': 'Thegospelcoalition.org'}
# 11                       {'id': None, 'name': 'Vox'}
# 55  {'id': None, 'name': 'Sciencebasedmedicine.org'}
# 16                  {'id': None, 'name': 'Phys.Org'}
# 10             {'id': None, 'name': 'Science Daily'}
# 22          {'id': None, 'name': 'Psychology Today'}
# 29                    {'id': None, 'name': 'Forbes'}
# 93                        {'id': 'rt', 'name': 'RT'}
# 0                   {'id': None, 'name': 'BBC News'}
# 70          {'id': None, 'name': 'Inside Higher Ed'}
# 26                    {'id': None, 'name': 'Forbes'}
# 27                    {'id': None, 'name': 'Forbes'}
# 28                    {'id': None, 'name': 'Forbes'}
# 60                  {'id': None, 'name': 'BBC News'}
# 78          {'id': None, 'name': 'Inside Higher Ed'}
# 32                    {'id': None, 'name': 'Forbes'}
# 67          {'id': None, 'name': 'Inside Higher Ed'}
# 31                    {'id': None, 'name': 'Forbes'}
# 84          {'id': None, 'name': 'Inside Higher Ed'}
# 74          {'id': None, 'name': 'Inside Higher Ed'}
# 29                    {'id': None, 'name': 'Forbes'}
# 41                    {'id': None, 'name': 'Forbes'}
# 76          {'id': None, 'name': 'Inside Higher Ed'}
# 82          {'id': None, 'name': 'Inside Higher Ed'}
# 75          {'id': None, 'name': 'Inside Higher Ed'}
# 79          {'id': None, 'name': 'Inside Higher Ed'}
# 30                    {'id': None, 'name': 'Forbes'}
#
#                                                author  \
# 52                                       Robin Hanson
# 53                                       David Gorski
# 1                                           Rob Stein
# 77                                   colleen.flaherty
# 88                                      Ronald Bailey
# 15                                    Brian Consiglio
# 96                                            Shannon
# 38  Chris Westfall, Contributor, \n Chris Westfall...
# 78                                   Elizabeth Redden
# 54                                       David Gorski
# 73                         joshua.m.kim@dartmouth.edu
# 65                                    Katherine Knott
# 69                                         Ryan Quinn
# 48                                     Kristin Kellen
# 11                                         Celia Ford
{'id': None, 'name': 'Sciencebasedmedicine.org'}
# 1                        {'id': None, 'name': 'NPR'}
# 77          {'id': None, 'name': 'Inside Higher Ed'}
# 88                    {'id': None, 'name': 'Reason'}
# 15                  {'id': None, 'name': 'Phys.Org'}
# 96              {'id': None, 'name': 'The Diplomat'}
# 38                    {'id': None, 'name': 'Forbes'}
# 78          {'id': None, 'name': 'Inside Higher Ed'}
# 54  {'id': None, 'name': 'Sciencebasedmedicine.org'}
# 73          {'id': None, 'name': 'Inside Higher Ed'}
# 65          {'id': None, 'name': 'Inside Higher Ed'}
# 69          {'id': None, 'name': 'Inside Higher Ed'}
# 48    {'id': None, 'name': 'Thegospelcoalition.org'}
# 11                       {'id': None, 'name': 'Vox'}
# 55  {'id': None, 'name': 'Sciencebasedmedicine.org'}
# 16                  {'id': None, 'name': 'Phys.Org'}
# 10             {'id': None, 'name': 'Science Daily'}
# 22          {'id': None, 'name': 'Psychology Today'}
# 29                    {'id': None, 'name': 'Forbes'}
# 93                        {'id': 'rt', 'name': 'RT'}
# 0                   {'id': None, 'name': 'BBC News'}
# 70          {'id': None, 'name': 'Inside Higher Ed'}
# 27                    {'id': None, 'name': 'Forbes'}
# 26                    {'id': None, 'name': 'Forbes'}
# 28                    {'id': None, 'name': 'Forbes'}
# 60                  {'id': None, 'name': 'BBC News'}
# 78          {'id': None, 'name': 'Inside Higher Ed'}
# 32                    {'id': None, 'name': 'Forbes'}
# 67          {'id': None, 'name': 'Inside Higher Ed'}
# 31                    {'id': None, 'name': 'Forbes'}
# 84          {'id': None, 'name': 'Inside Higher Ed'}
# 74          {'id': None, 'name': 'Inside Higher Ed'}
# 29                    {'id': None, 'name': 'Forbes'}
# 41                    {'id': None, 'name': 'Forbes'}
# 76          {'id': None, 'name': 'Inside Higher Ed'}
# 82          {'id': None, 'name': 'Inside Higher Ed'}
# 75          {'id': None, 'name': 'Inside Higher Ed'}
# 79          {'id': None, 'name': 'Inside Higher Ed'}
# 30                    {'id': None, 'name': 'Forbes'}
#
#                                                author  \
# 52                                       Robin Hanson
# 53                                       David Gorski
# 1                                           Rob Stein
# 77                                   colleen.flaherty
# 88                                      Ronald Bailey
# 15                                    Brian Consiglio
# 96                                            Shannon
# 38  Chris Westfall, Contributor, \n Chris Westfall...
# 78                                   Elizabeth Redden
# 54                                       David Gorski
# 73                         joshua.m.kim@dartmouth.edu
# 65                                    Katherine Knott
# 69                                         Ryan Quinn
# 48                                     Kristin Kellen
# 11                                         Celia Ford
# 55                                    Jonathan Howard
# 16                                      Jamie Pittock
# 10                                               None
# 22                           Loriann Oberlin MS, LCPC
# 29  Marybeth Gasman, Contributor, \n Marybeth Gasm...
# 93                                                 RT
# 0                                                None
# 70                                   Elizabeth Redden
# 27  Michael T. Nietzel, Senior Contributor, \n Mic...
# 26  Michael T. Nietzel, Senior Contributor, \n Mic...
# 28  Michael T. Nietzel, Senior Contributor, \n Mic...
# 31  https://imageio.forbes.com/specials-images/ima...  2024-11-09T08:02:13Z
# 84  https://www.insidehighered.com/sites/default/f...  2024-11-25T08:00:00Z
# 74  https://www.insidehighered.com/sites/default/f...  2024-11-11T08:00:00Z
# 29  https://imageio.forbes.com/specials-images/ima...  2024-11-25T18:33:33Z
# 41  https://imageio.forbes.com/specials-images/ima...  2024-12-04T20:24:23Z
# 76  https://www.insidehighered.com/sites/default/f...  2024-11-15T08:00:00Z
# 82  https://www.insidehighered.com/sites/default/f...  2024-12-05T08:00:00Z
# 75  https://www.insidehighered.com/modules/custom/...  2024-12-03T08:00:00Z
# 79  https://www.insidehighered.com/sites/default/f...  2024-11-25T08:00:00Z
# 30  https://imageio.forbes.com/specials-images/ima...  2024-12-07T02:27:41Z
#
#                                               content         topic
# 52  In health and medicine, we have many governmen...        Health
# 53  Last week, President-Elect Donald Trump rounde...        Health
# 1   As the next Trump administration overhauls the...        Health
# 77  The University of Virginia ramped up mental he...        Health
# 88  President-elect Donald Trump's nomination of R...        Health
# 15  The plague is one of the deadliest bacterial i...        Health
# 96  Karachi, Pakistan’s largest city and economic ...        Health
# 38  Gen Z is rethinking careers in healthcare, acc...        Health
# 78  We begin this essay with two key questions: Ar...        Health
# 54  Ever since antivaccine and pharma conspiracy t...        Health
# 73  How the World Ran Out of Everything: Inside th...        Health
# 65  President-elect Donald Trump nominated Dr. Jay...        Health
# 69  President-elect Trumps decision to nominate Ro...        Health
# 48  As a counseling professor, Ive sat with countl...        Health
# 11  Every year since 2019, Pew Research Center, a ...        Health
# 55  Sabotaging RFK Jr’s Confirmation Will Increase...        Health
# 16  Some A$13 billion in taxpayer dollars and 30 y...        Health
# 10  Time spent sedentary beyond six hours per day ...        Health
# 22  In a WordsRated.com survey, 65% of US adults e...        Health
# 29  Diversity of mental health\r\ngetty\r\nOn coll...        Health
# 93  A forum bringing together graduates of Soviet ...  Universities
# 0   Isobel, 18, decided she "did not want the debt...  Universities
# 70  Across the Anglophone world, universities are ...  Universities
# 27  Johns Hopkins University once again ranks firs...  Universities
# 26  Johns Hopkins University once again ranks firs...  Universities
# 28  The University of Michigan granted the most re...  Universities
# 60  Tuition fees for undergraduate degrees in Engl...  Universities
# 78  We begin this essay with two key questions: Ar...  Universities
# 32  The 2025 cohort of U.S. Rhodes Scholars has be...  Universities
# 67  Republicans are primed to ratchet up their eff...  Universities
# 31  Presidential election 2024 in United States of...  Universities
# 84  Colleges and universities are integrating life...  Universities
# 74  Each year, more 200,000 service members transi...  Universities
# 29  Diversity of mental health\r\ngetty\r\nOn coll...  Universities
# 41  Princeton University\r\nGetty Images\r\nWith t...  Universities
# 76  Amid a tense and polarized election cycle, con...  Universities
# 82  Academic probation, while designed to be a not...  Universities
# 75  In his opening keynote at the inaugural Interd...  Universities
# 79  An increasing number of Republican state offic...  Universities
# 30  Dance students rehearsing in studio\r\ngetty\r...  Universities
# 40 40

# %% [markdown]
# ### Sentiment Analysis Filtering

# %%
# Import sentiment analyzer from transformers
from transformers import pipeline
sentiment_analyzer = pipeline("sentiment-analysis", model="distilbert-base-uncased-finetuned-sst-2-english")

def analyze_sentiment(text):
    """Analyze sentiment of text and return score"""
    try:
        result = sentiment_analyzer(text[:256])[0] # Limit text length for speed
        return 1 if result['label'] == 'POSITIVE' else 0
    except:
        return 0 # Default to neutral if error

# Analyze mood_in sentiment
mood_sentiment = analyze_sentiment(mood_in)
# print(f"\nMood input sentiment score: {mood_sentiment}")

# Add sentiment scores
faiss_results['sentiment'] = faiss_results['content'].apply(analyze_sentiment)
hnsw_results['sentiment'] = hnsw_results['content'].apply(analyze_sentiment)

# Decide which articles to show
if mood_sentiment == 1:
    faiss_results_filtered = faiss_results
    hnsw_results_filtered = hnsw_results
else:
    faiss_results_filtered = faiss_results[faiss_results['sentiment'] == 1]
    hnsw_results_filtered = hnsw_results[hnsw_results["sentiment"] == 1]

# %% [markdown]
# ## Summarizer

# %%
# METHOD for SUMMARIZING ALL RELEVANT ARTICLES

def summarize_all_articles(df, max_articles):
    """
    Creates a single unified summary of multiple articles using Mistral
    Args:
        df: DataFrame containing articles (with 'content' and 'title' columns)
        max_articles: Maximum number of articles to include in summary
    Returns:
        str: A single summary combining all articles
    """
    # Combine titles and content (limited to max_articles)
    combined_text = ""
    for _, row in df.head(max_articles).iterrows():
        combined_text += f"{row['content']} "

    # Create prompt for single summary
    prompt = f"""Please provide ONE concise summary that captures the overall narrative 
    across all these articles as a single cohesive story. Do not summarize articles 
    individually. Focus on synthesizing the key themes and insights from all 
    {min(len(df), max_articles)} articles together:
    {combined_text}
    """

    # Get summary from Mistral
    response = ollama.chat(
        model="mistral", messages=[{"role": "user", "content": prompt}]
    )

    return response["message"]["content"]

# %%
hnsw_results_filtered.head(10)
# Out:
#                                         source  \
# 52  {'id': None, 'name': 'Overcomingbias.com'}
# 1                  {'id': None, 'name': 'NPR'}
# 77    {'id': None, 'name': 'Inside Higher Ed'}
# 15            {'id': None, 'name': 'Phys.Org'}
# 78    {'id': None, 'name': 'Inside Higher Ed'}
# 65    {'id': None, 'name': 'Inside Higher Ed'}
# 22    {'id': None, 'name': 'Psychology Today'}
# 29              {'id': None, 'name': 'Forbes'}
# 93                  {'id': 'rt', 'name': 'RT'}
# 27              {'id': None, 'name': 'Forbes'}
#
#                                                author  \
# 52                                       Robin Hanson
# 1                                           Rob Stein
# 77                                   colleen.flaherty
# 15                                    Brian Consiglio
# 78                                   Elizabeth Redden
# 65                                    Katherine Knott
# 22                           Loriann Oberlin MS, LCPC
# 29  Marybeth Gasman, Contributor, \n Marybeth Gasm...
# 93                                                 RT
# 27  Michael T. Nietzel, Senior Contributor, \n Mic...
#
#                                                 title  \
# 52                                No Meta Status Orgs
# 1   With Trump coming into power, the NIH is in th...
# 77  Survey: Supporting Students Postelection, in 4...
# 15  Q&A: Researcher discusses protecting the healt...
# 78       Imagining More Sustainable Higher Ed Careers
# 65                Trump Taps Bhattacharya to Lead NIH
# 22    Word Puzzles and Board Games Boost Brain Health
# 29  How To Support Faculty And Staff Who Support S...
# 93  Alumni of Russian universities gather in Cairo...
# 27  Johns Hopkins Again Tops NSF’s List Of Schools...
#
#                                           description  \
# 52  In health and medicine, we have many governmen...
